# %% [markdown]
# <a href="https://colab.research.google.com/github/khurshiduktamov/pneumonia-prediction/blob/master/Pneumonia_predictions_vgg16_bn_model_98__acc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES
# TO THE CORRECT LOCATION (/kaggle/input) IN YOUR NOTEBOOK,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

import os
import sys
from tempfile import NamedTemporaryFile
from urllib.request import urlopen
from urllib.parse import unquote, urlparse
from urllib.error import HTTPError
from zipfile import ZipFile
import tarfile
import shutil

CHUNK_SIZE = 40960
DATA_SOURCE_MAPPING = 'pnevmoniya:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-competitions-data%2Fkaggle-v2%2F36499%2F3618301%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240612%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240612T130139Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...'

KAGGLE_INPUT_PATH='/kaggle/input'
KAGGLE_WORKING_PATH='/kaggle/working'
KAGGLE_SYMLINK='kaggle'

# !umount /kaggle/input/ 2> /dev/null
shutil.rmtree('/kaggle/input', ignore_errors=True)
os.makedirs(KAGGLE_INPUT_PATH, 0o777, exist_ok=True)
os.makedirs(KAGGLE_WORKING_PATH, 0o777, exist_ok=True)

try:
  os.symlink(KAGGLE_INPUT_PATH, os.path.join("..", 'input'), target_is_directory=True)
except FileExistsError:
  pass
try:
  os.symlink(KAGGLE_WORKING_PATH, os.path.join("..", 'working'), target_is_directory=True)
except FileExistsError:
  pass

for data_source_mapping in DATA_SOURCE_MAPPING.split(','):
    directory, download_url_encoded = data_source_mapping.split(':')
    download_url = unquote(download_url_encoded)
    filename = urlparse(download_url).path
    destination_path = os.path.join(KAGGLE_INPUT_PATH, directory)
    try:
        with urlopen(download_url) as fileres, NamedTemporaryFile() as tfile:
            total_length = fileres.headers['content-length']
            print(f'Downloading {directory}, {total_length} bytes compressed')
            dl = 0
            data = fileres.read(CHUNK_SIZE)
            while len(data) > 0:
                dl += len(data)
                tfile.write(data)
                done = int(50 * dl / int(total_length))
                sys.stdout.write(f"\r[{'=' * done}{' ' * (50-done)}] {dl} bytes downloaded")
                sys.stdout.flush()
                data = fileres.read(CHUNK_SIZE)
            if filename.endswith('.zip'):
              with ZipFile(tfile) as zfile:
                zfile.extractall(destination_path)
            else:
              with tarfile.open(tfile.name) as tarfile:
                tarfile.extractall(destination_path)
            print(f'\nDownloaded and uncompressed: {directory}')
    except HTTPError as e:
        print(f'Failed to load (likely expired) {download_url} to path {destination_path}')
        continue
    except OSError as e:
        print(f'Failed to load {download_url} to path {destination_path}')
        continue

print('Data source import complete.')
# Out:
# Downloading pnevmoniya, 1222792613 bytes compressed
# [==================================================] 1222792613 bytes downloaded
# Downloaded and uncompressed: pnevmoniya
# Data source import complete.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# Streaming output truncated to the last 5000 lines.
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0458-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0526-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0439-0001-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0469-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0914-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0236-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0546-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0513-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0435-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1126-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0727-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0764-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0484-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0995-0001-0002.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0862-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0656-0001-0002.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0853-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0629-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1135-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1218-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0388-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0683-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0900-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0814-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0656-0001-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0487-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0634-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1116-0001-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0499-0001-0002.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0694-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0512-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1041-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1287-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1131-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0311-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0979-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0495-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0419-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0133-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0705-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1302-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0535-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1064-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0988-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0741-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1244-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0543-0001-0002.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0632-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0517-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0962-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1245-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0628-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0499-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0746-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0683-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0129-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0568-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1347-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1106-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1098-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0621-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0453-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1177-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0668-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0209-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0790-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0461-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1317-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0652-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1128-0001-0002.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0210-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0363-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0282-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1039-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1010-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0644-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0414-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0751-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1158-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0573-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0846-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1152-0001-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0115-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0647-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0857-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0849-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0974-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0164-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0437-0001-0002.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0261-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0182-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1020-0001-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0748-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0467-0001-0002.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0662-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0947-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0819-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0698-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0971-0001-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0677-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0397-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0250-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0299-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1345-0001-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0746-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0851-0001-0002.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0346-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1222-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0568-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0659-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0525-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1258-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0549-0001-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0315-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0994-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0416-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0633-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0842-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0596-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0626-0001-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1332-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0143-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1054-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0539-0001-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0357-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0728-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0595-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0618-0001-0002.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0485-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0523-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0395-0001-0002.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0829-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0453-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0505-0001-0002.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1056-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0592-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1272-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0365-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0650-0001-0002.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0503-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0575-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0686-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1320-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0868-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0448-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0905-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1103-0001-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0353-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0640-0001-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0558-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1089-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0526-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0408-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1120-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0622-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0244-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0888-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1168-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0541-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0967-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0525-0001-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0809-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0205-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0391-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0875-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0872-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0437-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0637-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0882-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0807-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1062-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0534-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0447-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0559-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0402-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0531-0001-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0934-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0983-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1266-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0933-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1084-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0601-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0544-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1040-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0710-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0596-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0906-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1314-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0374-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1048-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0539-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0482-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0245-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1130-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1049-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0448-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1094-0001-0002.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0551-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0986-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0529-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0664-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1047-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0408-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0276-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0590-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0603-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0229-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0566-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0446-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0631-0001-0002.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0641-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0741-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0463-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0619-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0452-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0166-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0653-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0722-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0305-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0543-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0646-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0416-0001-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0394-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1045-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0238-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1150-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1277-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0896-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1291-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1142-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0547-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0775-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0421-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0430-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0561-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0977-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0395-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0673-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0682-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0695-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0622-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0439-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1282-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0620-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0894-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0399-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0929-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1176-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0689-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0393-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0740-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0385-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0475-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0172-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0332-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0384-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1033-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0978-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0413-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1285-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0908-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0304-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0965-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0935-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0390-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0907-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0280-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0140-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0475-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0514-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0780-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0582-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0553-0001-0003.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1156-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1006-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0659-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1275-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0350-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0440-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0551-0001-0002.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0774-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0483-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0433-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0641-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1030-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0995-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1256-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0509-0001-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0709-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0909-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0273-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0292-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0523-0001-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1114-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1188-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0537-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0222-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0952-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1154-0001-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0400-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1376-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0981-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0214-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0609-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1422-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1278-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0406-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0447-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0660-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1157-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0667-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0389-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1132-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0669-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1102-0001-0002.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0456-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0998-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0239-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1005-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0893-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0606-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0226-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0168-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0717-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0427-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0702-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1190-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0566-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0262-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0547-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0473-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0419-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0509-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0237-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0335-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1155-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1004-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1086-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1027-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1035-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1327-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0199-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0476-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1240-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0555-0001-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0156-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0339-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0647-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0530-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0466-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0832-0001-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0644-0001-0002.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0193-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0455-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0264-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0401-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0415-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0224-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1182-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1305-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0478-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0308-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0660-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0648-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1300-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0394-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1052-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0449-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1321-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0643-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0772-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0389-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1306-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0418-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1250-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1242-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0892-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0932-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0191-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0428-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0629-0001-0003.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0383-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0636-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0183-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0613-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1189-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0203-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0527-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0474-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1311-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0122-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0612-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0170-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0587-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1124-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0627-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1274-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0362-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0863-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0431-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0385-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0500-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0187-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0750-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0195-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1307-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0518-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0521-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0655-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1304-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1024-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0491-0001-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1127-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0421-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0693-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0944-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0450-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0298-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0584-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1221-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0999-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0890-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1269-0001-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1145-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0729-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0665-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0467-0001-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0147-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0874-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0213-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1060-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0752-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1194-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1011-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0520-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1400-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0703-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0851-0001-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0323-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0642-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0507-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1125-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0645-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1051-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0650-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1008-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0340-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0509-0001-0002.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1153-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0583-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1330-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1160-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0313-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0443-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0651-0004.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0730-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0877-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0290-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0180-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0640-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1243-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0586-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0557-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1294-0001-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1019-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0277-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0599-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0268-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0499-0001-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1419-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0781-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1247-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0657-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0435-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0681-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0675-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0449-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0189-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0552-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0860-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0384-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0608-0001-0002.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0696-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0392-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1020-0001-0002.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0619-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1262-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0343-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0910-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0154-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0852-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0859-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0693-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1315-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0409-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0477-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0493-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0983-0001-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0329-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0445-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0830-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0561-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0607-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0642-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0735-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0387-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1183-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0557-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1122-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0231-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0918-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0551-0001-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0630-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0808-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0618-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0650-0001-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0185-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0651-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0454-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0757-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1308-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0487-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0654-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0845-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0272-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0662-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0383-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1198-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1147-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0652-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0367-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0629-0001-0002.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0361-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0463-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0289-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0496-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0649-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1169-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0926-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0451-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0117-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0668-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0627-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1090-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0885-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0274-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0333-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0533-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0176-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1116-0001-0002.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0497-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0687-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0648-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0661-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1234-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0674-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0151-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1058-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0478-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0476-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0493-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0871-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0922-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0858-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1091-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0797-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1180-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1108-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0660-0001-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0666-0001-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0125-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1136-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0472-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0704-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0676-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0976-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0423-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0520-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0508-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0812-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0701-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0488-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0427-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0505-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1319-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0338-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0564-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1328-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0839-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0880-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0949-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0666-0001-0002.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1201-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0490-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0623-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0753-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0699-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1167-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0715-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0499-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0577-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0843-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0634-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0531-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0563-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1261-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0737-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0452-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0127-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0467-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0345-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0661-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0369-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1179-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1043-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0815-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1116-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0625-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0396-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0723-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0489-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0225-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0765-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0652-0001-0002.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0640-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0837-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0465-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1232-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0601-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1362-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0620-0001-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0578-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1202-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1412-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0618-0001-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0919-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1109-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0711-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0145-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1123-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1303-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0517-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0555-0001-0002.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1197-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0739-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0307-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0395-0001-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0227-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0523-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0598-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0555-0001-0002.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0705-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1059-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0644-0001-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0428-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0989-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0293-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1276-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0552-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0460-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0997-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0649-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1345-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0349-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0583-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0152-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0987-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0255-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1258-0001-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0221-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0617-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0650-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0536-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0355-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1342-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0555-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0631-0001-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0149-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0294-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0776-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0215-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1014-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0623-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1154-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0160-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1350-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0724-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0966-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0243-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1102-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0719-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0411-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1257-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0542-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0135-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0324-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0437-0001-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0727-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0545-0001-0002.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1322-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0489-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1333-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0441-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1280-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0742-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0624-0001-0002.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1337-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0832-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0810-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1281-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0836-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0545-0001-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0744-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1015-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0838-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0538-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0579-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0512-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0462-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0771-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1111-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0453-0001-0002.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0486-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0700-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0424-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0600-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0513-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1360-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0491-0001-0002.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0821-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0736-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1203-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0604-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0219-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1329-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1286-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0501-0001-0002.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0793-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0941-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0325-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0685-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1296-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0630-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0960-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0581-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1191-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1094-0001-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0432-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0946-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1093-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0580-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1073-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1088-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0866-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0599-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1128-0001-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0876-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0425-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0620-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0654-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0455-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0957-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0757-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0550-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0354-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0391-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0241-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0881-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0347-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0465-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0961-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0464-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0851-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0251-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0865-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1053-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0670-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0206-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0873-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1269-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0555-0001-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0444-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0595-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-1254-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0472-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/NORMAL2-IM-0417-0001.jpeg
# /kaggle/input/pnevmoniya/train/NORMAL/IM-0692-0001.jpeg
# ...
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person736_virus_1358.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person530_bacteria_2233.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person455_bacteria_1947.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person586_bacteria_2420.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1031_virus_1723.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1494_virus_2601.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person850_bacteria_2771.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person370_bacteria_1691.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1547_virus_2688.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1238_virus_2098.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person625_virus_1199.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person509_bacteria_2145.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1361_bacteria_3477.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1338_bacteria_3394.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1893_bacteria_4781.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1103_virus_1825.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person841_bacteria_2760.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person366_virus_746.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1019_virus_1708.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person5_bacteria_16.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person586_virus_1130.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1549_bacteria_4050.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person71_bacteria_347.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1411_bacteria_3593.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1020_virus_1710.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person348_bacteria_1601.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1231_bacteria_3186.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person624_bacteria_2497.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person441_bacteria_1912.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person296_bacteria_1396.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person960_virus_1633.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person277_bacteria_1301.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1683_bacteria_4460.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1496_bacteria_3910.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1460_virus_2507.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1349_bacteria_3436.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person115_virus_219.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1679_bacteria_4453.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1637_bacteria_4339.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1757_bacteria_4599.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1345_bacteria_3428.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person965_virus_1638.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person298_bacteria_1412.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person413_bacteria_1833.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person547_virus_1086.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1160_bacteria_3105.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1372_bacteria_3502.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1080_bacteria_3020.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person351_bacteria_1624.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person493_bacteria_2087.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1883_bacteria_4769.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person464_virus_956.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1262_bacteria_3220.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person674_bacteria_2568.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person486_bacteria_2052.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person49_bacteria_237.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1499_virus_2609.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person9_bacteria_38.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1585_bacteria_4155.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person891_virus_1541.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person605_virus_1169.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person325_bacteria_1498.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person382_bacteria_1746.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1550_bacteria_4051.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person691_bacteria_2588.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1010_virus_1695.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person266_virus_549.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1938_bacteria_4854.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person502_bacteria_2118.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person949_bacteria_2874.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person441_virus_895.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person77_bacteria_375.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1270_bacteria_3230.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person603_bacteria_2461.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1474_virus_2557.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person520_bacteria_2203.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1379_bacteria_3514.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1403_bacteria_3559.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person467_bacteria_1988.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1544_bacteria_4038.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person131_virus_265.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person291_bacteria_1374.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person354_bacteria_1634.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1316_virus_2271.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1320_bacteria_3347.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1598_bacteria_4195.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1294_virus_2221.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person151_virus_302.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1171_bacteria_3118.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person325_virus_665.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1855_bacteria_4727.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person518_bacteria_2198.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person859_virus_1504.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person30_bacteria_148.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1067_virus_1770.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person556_bacteria_2326.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1613_bacteria_4247.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person810_virus_1446.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person778_virus_1408.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1180_virus_2013.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1700_bacteria_4502.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1393_virus_2396.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person23_bacteria_89.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person111_virus_210.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person531_bacteria_2239.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person471_bacteria_2006.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1220_bacteria_3173.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1473_virus_2551.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person540_bacteria_2271.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1069_virus_1772.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1413_bacteria_3620.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person779_virus_1410.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person437_bacteria_1884.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1082_bacteria_3022.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1361_virus_2344.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person468_bacteria_1991.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1116_virus_1841.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person102_virus_189.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person490_bacteria_2070.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person497_virus_1005.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person124_virus_250.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person548_bacteria_2299.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person298_bacteria_1408.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person843_bacteria_2763.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person458_bacteria_1955.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person585_virus_1129.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person475_virus_972.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1639_bacteria_4345.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person300_virus_621.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person876_bacteria_2799.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person359_bacteria_1642.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1274_virus_2193.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1548_virus_2689.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1234_virus_2093.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person596_bacteria_2446.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1576_bacteria_4122.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person509_virus_1024.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1590_bacteria_4174.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person762_virus_1390.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person55_bacteria_264.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person268_virus_553.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1338_bacteria_3397.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1483_bacteria_3876.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person336_bacteria_1551.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1709_bacteria_4522.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person413_bacteria_1832.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1327_bacteria_3374.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1724_bacteria_4549.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person825_bacteria_2736.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1005_bacteria_2936.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person339_bacteria_1574.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person855_virus_1500.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person458_bacteria_1954.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person574_virus_1118.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person3_bacteria_12.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1546_bacteria_4044.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1288_bacteria_3251.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person66_bacteria_326.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1438_virus_2452.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person457_bacteria_1949.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person70_bacteria_341.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person637_virus_1218.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1345_bacteria_3427.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person501_bacteria_2112.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person582_bacteria_2404.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person753_virus_1378.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1730_bacteria_4559.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person481_virus_983.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1310_bacteria_3304.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person332_bacteria_1533.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person516_bacteria_2192.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person6_bacteria_22.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person952_bacteria_2877.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1595_virus_2771.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1338_virus_2308.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1205_bacteria_3157.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1269_virus_2162.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person267_bacteria_1252.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person331_virus_684.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person371_bacteria_1694.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person531_bacteria_2235.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1180_virus_2012.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person547_bacteria_2296.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1488_virus_2593.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person661_virus_1245.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person19_bacteria_58.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person660_virus_1244.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person868_virus_1514.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1628_bacteria_4293.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person423_bacteria_1857.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person334_bacteria_1545.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1077_virus_1787.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1352_bacteria_3445.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1263_bacteria_3221.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1697_bacteria_4496.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1405_bacteria_3567.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person355_virus_731.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person522_bacteria_2210.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1917_bacteria_4823.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person880_virus_1529.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person332_virus_685.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person318_virus_644.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1363_bacteria_3483.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person957_virus_1629.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person528_bacteria_2227.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person494_bacteria_2090.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person970_bacteria_2895.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person33_bacteria_169.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person867_virus_1512.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person74_bacteria_362.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1568_virus_2723.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person961_virus_1634.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person66_bacteria_323.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1099_bacteria_3040.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1306_bacteria_3272.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person380_virus_763.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person926_virus_1583.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1072_bacteria_3007.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person735_bacteria_2638.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1259_bacteria_3217.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person500_bacteria_2109.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1180_virus_2011.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1133_virus_1865.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1511_bacteria_3955.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person277_bacteria_1302.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1541_virus_2681.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person101_virus_187.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1429_bacteria_3691.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1176_bacteria_3123.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person820_virus_1456.jpeg
# /kaggle/input/pnevmoniya/train/PNEUMONIA/person1595_bacteria_4183.jpeg

# %% [markdown]
# # **CRISP-DM**
# <img src="https://datafifty.com/wp-content/uploads/2022/02/crispdm-_2_.webp" alt="CRISP-DM" >

# %% [markdown]
# # **Business Understanding**

# %% [markdown]
# Pneumonia accounts for more than 15% of deaths in children under 5 years of age internationally. In 2015, 920,000 children under the age of 5 died from this disease. In the United States, pneumonia accounted for more than 500,000 emergency department visits per year and more than 50,000 deaths in 2015, making it one of the top 10 causes of death in the country. Although pneumonia is common, it is very difficult to make an accurate diagnosis. This requires review of the chest radiograph (CXR) by highly trained specialists and confirmation by clinical history, vital signs, and laboratory tests. Pneumonia usually appears as a hazy area or haziness on CXR. However, the diagnosis of pneumonia on CXR is complicated by a number of other conditions such as fluid overload in the lungs (pulmonary edema), hemorrhage, volume loss (atelectasia or collapse), lung cancer, or changes following radiation or surgery. . Fluid in the pleural space outside the lungs (pleural effusion) also appears as an increase in opacity on CXR. When available, comparison of the patient's CXRs obtained at different time points and correlation with clinical symptoms and history may aid in the diagnosis.
#
# I am taking part in this competition to try to solve this problem!
#
# * It needs to be diagnosed, so it is classification problem.
# * [In this work, a deep learning(DL) model using VGG16 is utilized for detecting and classifying pneumonia using two CXR image datasets. The VGG16 with Neural Networks (NN) provides an accuracy value of 92.15%, recall as 0.9308, precision as 0.9428, and F1-Score0.937 for the first dataset. ](https://www.sciencedirect.com/science/article/pii/S1877050923000182)

# %%
import torch
import fastai
from fastai.vision.all import *
from ipywidgets import widgets

print(torch.__version__)
print(fastai.__version__)
# Out:
# 2.3.0+cu121
# 2.7.15

# %% [markdown]
# # **Data understanding and preparation**

# %%
#Path
path = Path('/kaggle/input/pnevmoniya/train')
fls = get_image_files(path)  # fastai method to see the files inside of the path
failed = verify_images(path) # fastai method to check if pictures are corrupted
# fls
print(f'corrupted images: {failed}')
# Out:
# 'PosixPath' object is not iterable
# corrupted images: []

# %% [markdown]
# **Data loaders**
# Pytorch is getting data as data loaders

# %%
cxr = DataBlock(
    blocks = (ImageBlock, CategoryBlock), # ImageBlock - bcoz we are working with pics, CategoryBlock - bcoz our data divided into categories.
    get_items = get_image_files, # To get images uses fastai method
    splitter = RandomSplitter(valid_pct = 0.2, seed=42), # To split the data to train and validation sets
    get_y = parent_label, # Assigns each pictures folder name as pics label. FastAI
    item_tfms = Resize(224)
)

# Data Loaders
dls = cxr.dataloaders(path)

# %%
dls.train.show_batch(max_n=32, nrows=4)

# %% [markdown]
# # **Modeling and Evalution**

# %%
learn = cnn_learner(dls, vgg16_bn, metrics=accuracy) # vision_learner(dls, vgg16_bn, metrics=accuracy)
learn.fine_tune(4)
# Out:
# /usr/local/lib/python3.10/dist-packages/fastai/vision/learner.py:301: UserWarning: `cnn_learner` has been renamed to `vision_learner` -- please update your code
#   warn("`cnn_learner` has been renamed to `vision_learner` -- please update your code")
# Downloading: "https://download.pytorch.org/models/vgg16_bn-6c64b313.pth" to /root/.cache/torch/hub/checkpoints/vgg16_bn-6c64b313.pth
# 100%|██████████| 528M/528M [00:07<00:00, 71.9MB/s]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.422840</td>
#       <td>0.164380</td>
#       <td>0.944391</td>
#       <td>02:04</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.136431</td>
#       <td>0.133551</td>
#       <td>0.961649</td>
#       <td>02:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.084490</td>
#       <td>0.057919</td>
#       <td>0.982742</td>
#       <td>02:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.039157</td>
#       <td>0.048333</td>
#       <td>0.985618</td>
#       <td>02:11</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.027121</td>
#       <td>0.056501</td>
#       <td>0.983701</td>
#       <td>02:12</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Evaluation
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
interp.plot_top_losses(4, nrows=1)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
learn.export('pneumonia_classification_model.pkl')

# %%
import os

# Directory containing test images
test_dir = '/kaggle/input/pnevmoniya/test'

# Get a list of test image file paths
test_files = get_image_files(test_dir)

# Sort the file paths in ascending order based on the filenames
test_files = sorted(test_files)

# Create an empty list to store predictions
predictions = []

# Iterate over test images
for img_path in test_files:
    # Extract image ID from the file name
    img_id = os.path.basename(img_path)  # Extract filename including extension

    # Load and preprocess the test image
    img = PILImage.create(img_path)
    img = img.resize((224, 224))  # Resize to match the input size of the model

    # Make predictions
    pred_class, _, _ = learn.predict(img)

    # Determine label
    label = 1 if pred_class == 'PNEUMONIA' else 0

    # Append predictions to the list
    predictions.append({'id': img_id, 'labels': label})

# Convert predictions list to DataFrame
predictions_df = pd.DataFrame(predictions)

# Save predictions to a CSV file
predictions_df
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
# ...
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#                       id  labels
# 0    test_img_10001.jpeg       1
# 1    test_img_10002.jpeg       0
# 2    test_img_10003.jpeg       0
# 3    test_img_10004.jpeg       1
# 4    test_img_10005.jpeg       0
# ..                   ...     ...
# 619  test_img_10620.jpeg       1
# 620  test_img_10621.jpeg       0
# 621  test_img_10622.jpeg       1
# 622  test_img_10623.jpeg       1
# 623  test_img_10624.jpeg       1
#
# [624 rows x 2 columns]

# %% [markdown]
# # **Output**

# %%
# Save predictions to a CSV file
# predictions_df.drop('prediction', axis=1, inplace=True)
predictions_df['id'].sort_values(ascending=True)
predictions_df.to_csv('predictions.csv', index=False)
